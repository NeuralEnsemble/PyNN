# %%
from pyNN.morphology import NeuroMLMorphology, load_morphology, uniform, random_section, dendrites, apical_dendrites, by_distance
import pyNN.arborproto as sim

# %%
neurml_morph = load_morphology("oi15rpy4-1.CNG.swc", replace_axon=None)

# %%
poiss.model
# Out:
# pyNN.arbor.cells.RandomSpikeSource

# %%
poiss.model.parameter_names
# Out:
# ('start', '_interval', 'duration')

# %%
class Foo(object):
    def __init__(self, **param):
        for ky in param.keys():
            print(ky)

# %%
Foo(rate=12)
# Out:
# rate

# %%
inputs = sim.Population(1000, sim.SpikeSourcePoisson(rate=1000.0))

# %%
len(inputs.all_cells)
# Out:
# 1000

# %%
inputs.all_cells[0].
# Out:
# Help on ID in module pyNN.arbor.simulator object:
#
# class ID(builtins.int, pyNN.common.populations.IDMixin)
#  |  ID(n)
#  |
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Method resolution order:
#  |      ID
#  |      builtins.int
#  |      pyNN.common.populations.IDMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
# ...
